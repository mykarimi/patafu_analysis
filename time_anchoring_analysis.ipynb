# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %%
sns.set(color_codes=True)
sns.set_context
np.random.seed(sum(map(ord, "categorical")))
a_time = sns.load_dataset("a_time")
sns.swarmplot(x="Time Anchoring Parameter", y="F-measure", hue="Evaluation", data=a_time, size=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
print('INTRA-PERIODIC EVENT COREFERENCE EVALUATION OF ONE EVENTINSTANCE')
sns.plt.show()
# Out:
# INTRA-PERIODIC EVENT COREFERENCE EVALUATION OF ONE EVENTINSTANCE

# %%
sns.set(color_codes=True)
sns.set_context
np.random.seed(sum(map(ord, "categorical")))
a_time2 = sns.load_dataset("a_time2")
sns.swarmplot(x="Time Anchoring Parameter", y="F-measure", hue="Evaluation", data=a_time2, size=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
print('INTRA-PERIODIC EVENT COREFERENCE EVALUATION OF ONE EVENTINSTANCE')
sns.plt.show()
# Out:
# INTRA-PERIODIC EVENT COREFERENCE EVALUATION OF ONE EVENTINSTANCE

# %%
sns.set(color_codes=False)
sns.set_context
np.random.seed(sum(map(ord, "categorical")))
b_time = sns.load_dataset("b_time")
sns.swarmplot(x="Time Anchoring Parameter", y="F-measure", hue="Evaluation", data=b_time, size=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
print('INTERPERIODIC EVENT COREFERENCE EVALUATION OF ONE EVENTINSTANCE')
sns.plt.show()
# Out:
# INTERPERIODIC EVENT COREFERENCE EVALUATION OF ONE EVENTINSTANCE

# %%
sns.set(color_codes=False)
sns.set_context
np.random.seed(sum(map(ord, "categorical")))
b_time2 = sns.load_dataset("b_time2")
sns.swarmplot(x="Time Anchoring Parameter", y="F-measure", hue="Evaluation", data=b_time2, size=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
print('INTERPERIODIC EVENT COREFERENCE EVALUATION OF ONE EVENTINSTANCE')
sns.plt.show()
# Out:
# INTERPERIODIC EVENT COREFERENCE EVALUATION OF ONE EVENTINSTANCE

# %%
sns.set(color_codes=False)
sns.set_context
np.random.seed(sum(map(ord, "categorical")))
c_time = sns.load_dataset("c_time")
sns.swarmplot(x="Time Anchoring Parameter", y="F-measure", hue="Evaluation", data=c_time, size=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
print('INTRA-PERIODIC EVENT COREFERENCE EVALUATION OF TWO EVENT INSTANCES')
sns.plt.show()
# Out:
# INTRA-PERIODIC EVENT COREFERENCE EVALUATION OF TWO EVENT INSTANCES

# %%
sns.set(color_codes=False)
sns.set_context
np.random.seed(sum(map(ord, "categorical")))
c_time2 = sns.load_dataset("c_time2")
sns.swarmplot(x="Time Anchoring Parameter", y="F-measure", hue="Evaluation", data=c_time2, size=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
print('INTRA-PERIODIC EVENT COREFERENCE EVALUATION OF TWO EVENT INSTANCES')
sns.plt.show()
# Out:
# INTRA-PERIODIC EVENT COREFERENCE EVALUATION OF TWO EVENT INSTANCES

# %%
sns.set(color_codes=False)
sns.set_context
np.random.seed(sum(map(ord, "categorical")))
d_time = sns.load_dataset("d_time")
sns.swarmplot(x="Time Anchoring Parameter", y="F-measure", hue="Evaluation", data=d_time, size=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
print('INTRA-PERIODIC EVENT COREFERENCE EVALUATION OF TWO DIFFERENT EVENT INSTANCES WITH EACH OTHER')
sns.plt.show()
# Out:
# INTRA-PERIODIC EVENT COREFERENCE EVALUATION OF TWO DIFFERENT EVENT INSTANCES WITH EACH OTHER

# %%
sns.set(color_codes=False)
sns.set_context
np.random.seed(sum(map(ord, "categorical")))
d_time2 = sns.load_dataset("d_time2")
sns.swarmplot(x="Time Anchoring Parameter", y="F-measure", hue="Evaluation", data=d_time2, size=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
print('INTRA-PERIODIC EVENT COREFERENCE EVALUATION OF TWO DIFFERENT EVENT INSTANCES WITH EACH OTHER')
sns.plt.show()
# Out:
# INTRA-PERIODIC EVENT COREFERENCE EVALUATION OF TWO DIFFERENT EVENT INSTANCES WITH EACH OTHER

# %%
sns.set(color_codes=True)
sns.set_context
np.random.seed(sum(map(ord, "categorical")))
e_time = sns.load_dataset("e_time")
sns.swarmplot(x="Time Anchoring Parameter", y="F-measure", hue="Evaluation", data=e_time, size=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
print('INTRA-PERIODIC EVENT COREFERENCE EVALUATION OF TWO EVENTINSTANCE - ALL SUBCORPORA TOGETHER')
sns.plt.show()
# Out:
# INTRA-PERIODIC EVENT COREFERENCE EVALUATION OF TWO EVENTINSTANCE - ALL SUBCORPORA TOGETHER
